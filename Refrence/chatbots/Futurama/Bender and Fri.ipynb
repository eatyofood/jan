# %%
import pandas as pd
import numpy as np
#import cufflinks as cf
#cf.go_offline(connected=False)
import os

# %%
os.listdir()
# Out:
# ['parsed_checkpoint.csv',
#  'db.sqlite3',
#  '.ipynb_checkpoints',
#  'Untitled1.ipynb',
#  'futurama_scripts.txt',
#  'Futurama_Dialog.csv',
#  'db.sqlite3-shm',
#  'db.sqlite3-wal',
#  'sentence_tokenizer.pickle',
#  'Untitled.ipynb']

# %%
df = pd.read_csv('Futurama_Dialog.csv')
df['prev_name'] = df['name'].shift()
df
# Out:
#              name                                               dail  \
# 0             Fry   Space. It seems to go on and on forever. But ...
# 1             Fry                             how you play the game!
# 2             Boy                                  You stink, loser!
# 3         Panucci                 Hey, Fry. Pizza goin' out! C'mon!!
# 4             Fry                   Michelle, baby! Where you going?
# ...           ...                                                ...
# 28387      Hermes            Sweet topology of cosmology, it's huge!
# 28388  Farnsworth   If we fly into it, it could take us trillions...
# 28389         Fry                What do we do? Should we go for it?
# 28390      Bender                                                NaN
# 28391         ALL            Go, go, go, go, go, go, go, go, go, go.
#
#                                                     prev   prev_name
# 0                                                    NaN         NaN
# ...

# %%
#pd.set_option('display.max_rows',None)

# %%
c   = 'Futurama'
#cdf = df[df['name']==c].dropna()
cdf = cdf.reset_index()
cdf
# Out:
#       index name                                               dail  \
# 0         1  Fry                             how you play the game!
# 1         4  Fry                   Michelle, baby! Where you going?
# 2         6  Fry    I hate my life, I hate my life, I hate my life.
# 3         8  Fry                Here's to another lousy millennium.
# 4        19  Fry                                        What the--?
# ...     ...  ...                                                ...
# 3958  28369  Fry                               Hutch, are you okay?
# 3959  28377  Fry   Huh. I thought you only saved the DNA of enda...
# 3960  28383  Fry   Well, this is the end. There was so many thin...
# 3961  28385  Fry   Like this is not the end. But mostly just, I ...
# 3962  28389  Fry                What do we do? Should we go for it?
#
#                                                    prev   prev_name
# 0      Space. It seems to go on and on forever. But ...         Fry
# ...

# %%
from tqdm import trange

# %%
li = []
iterations    = len(cdf)
for i in trange(iterations):
    li.append(cdf['prev'].iloc[i])
    li.append(cdf['dail'].iloc[i])
print(len(cdf))
pd.DataFrame(li)
# Out:
# 100%|██████████| 3963/3963 [00:00<00:00, 53569.33it/s]
# 3963
#                                                       0
# 0      Space. It seems to go on and on forever. But ...
# 1                                how you play the game!
# 2                    Hey, Fry. Pizza goin' out! C'mon!!
# 3                      Michelle, baby! Where you going?
# 4                 I put your stuff out on the sidewalk!
# ...                                                 ...
# 7921   Well, this is the end. There was so many thin...
# 7922                                         Like what?
# 7923   Like this is not the end. But mostly just, I ...
# 7924   If we fly into it, it could take us trillions...
# 7925                What do we do? Should we go for it?
#
# [7926 rows x 1 columns]

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer

# Create a new chat bot named Charlie
chatbot = ChatBot(c)

trainer = ListTrainer(chatbot)

trainer.train(li)

#    "Hi, can I help you?",
#    "Sure, I'd like to book a flight to Iceland.",
#    "Your flight has been booked."
#])#

# Get a response to the input text 'I would like to book a flight.'
response = chatbot.get_response('I would like to book a flight.')
print(response)
# Out:
# List Trainer: [                    ] 0%
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/brando/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /home/brando/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# List Trainer: [####################] 100%
# No!

# %%
if '' == True:
    req      = str(input('YOU: '))
    response = chatbot.get_response(req)
    print(c,': ',response)

# %%
import pyttsx3
import time

# %%
eng = pyttsx3.init()
eng.setProperty('rate',200)
eng.setProperty('voice','english+f4')

def say(words):
    
    #os.system('figlet {}'.format(words))
    
    eng.say(words)
    eng.runAndWait()

say('hello')
eng.setProperty('voice','english')
say('hi there')

# %%
Bender = ChatBot('Bender')
ben_resp = None
while True:
    if ben_resp == None:
        ben_resp = "crap where did that come from "
    eng.setProperty('voice','english+f4')
    response = chatbot.get_response(ben_resp)
    print(c,': ',response)
    say(response)
    #time.sleep(1)
    eng.setProperty('voice','english')
    ben_resp= Bender.get_response(response)
    print('Bender:',ben_resp)
    say(ben_resp)
    #time.sleep(0.3)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/brando/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to /home/brando/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Fry :  You try it and I'll bash yo' face in!
# Bender: Ooh! I'm so scared...no-arms!
# Fry :  He looks like Bender!
# Bender: Oh, no no no! No way am I that kid's dad!
# Fry :  Wipe my tiny metal ass!
# Bender: Hey! Those jerklings ate my couch.
# Fry :  Like the Kardashians.
# Bender: Now they drank my booze?! They've gone too far!
# Fry :  Of course! Long before the Benders devour the Earth, they'll deplete the planet's booze and die off. This is a problem that will solve itself.
# Bender: A problem that solves itself? That sounds like a job for me, Bender.
# Fry :  A greater tragedy my eyes have never beheld. Well, into the terlet.
# ...
