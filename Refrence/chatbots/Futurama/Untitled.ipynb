# %%
import pandas as pd
import pretty_errors
#from Janet import typewords
from pynput.keyboard import Key, Controller
import shutil 
from tqdm import trange
import time
import os
from datetime import datetime
import pyttsx3

# %%
#!python3 --version
# Out:
# Python 3.8.5

# %%
li = []
with open('futurama_scripts.txt') as file:
    for line in file.readlines():
        li.append(line)
        
df = pd.DataFrame(li)

# %%
df['raw'] = df[0].str.replace('\n','')
df
# Out:
#                                                        0  \
# 0      Fry: Space. It seems to go on and on forever. ...
# 1                           Fry how you play the game!\n
# 2                               Boy: You stink, loser!\n
# 3          Panucci: Hey, Fry. Pizza goin' out! C'mon!!\n
# 4                Fry: Michelle, baby! Where you going?\n
# ...                                                  ...
# 28387  Hermes: Sweet topology of cosmology, it's huge!\n
# 28388  Farnsworth: If we fly into it, it could take u...
# 28389         Fry: What do we do? Should we go for it?\n
# 28390                                           Bender\n
# 28391     ALL: Go, go, go, go, go, go, go, go, go, go.\n
#
#                                                      raw
# 0      Fry: Space. It seems to go on and on forever. ...
# 1                             Fry how you play the game!
# 2                                 Boy: You stink, loser!
# ...

# %%
def split_text(s):
    if ':' in s:
        c = s.split(':')[0]
    else:
        try:
            c = s.split(' ')[0]
        except:
            c = ''
    #d = d.replace((c+':'),'')
    
    return c
df
# Out:
#                                                        0  \
# 0      Fry: Space. It seems to go on and on forever. ...
# 1                           Fry how you play the game!\n
# 2                               Boy: You stink, loser!\n
# 3          Panucci: Hey, Fry. Pizza goin' out! C'mon!!\n
# 4                Fry: Michelle, baby! Where you going?\n
# ...                                                  ...
# 28387  Hermes: Sweet topology of cosmology, it's huge!\n
# 28388  Farnsworth: If we fly into it, it could take u...
# 28389         Fry: What do we do? Should we go for it?\n
# 28390                                           Bender\n
# 28391     ALL: Go, go, go, go, go, go, go, go, go, go.\n
#
#                                                      raw        name
# 0      Fry: Space. It seems to go on and on forever. ...         Fry
# 1                             Fry how you play the game!         Fry
# 2                                 Boy: You stink, loser!         Boy
# ...

# %%
pd.set_option('display.max_rows',200)

# %%
df['dail'] =df['raw'].str.split(':',expand=True)[1]

# %%
for i in trange(len(df)):
    if df['dail'][i] == None:
        df['dail'][i] = df['raw'][i].replace(df['name'][i],'')
# Out:
# 100%|██████████| 28392/28392 [00:05<00:00, 4806.30it/s]

# %%
df[df['name']=='Bender']
# Out:
#                                                        0  \
# 71                Bender: Shinier than yours, meatbag!\n
# 72     Bender: Listen, buddy, I'm in a hurry here. Le...
# 76                           Bender Bring it on, baby!\n
# 77     Bender: C'mon, c'mon! Kill me already! By the ...
# 80     Bender Well, I didn't have anything else plann...
# ...                                                  ...
# 28298  Bender Green Bluebird, this is Mr. Fabulous. W...
# 28340                         Bender: No! Don't do it!\n
# 28343       Bender: And hookers, don't forget hookers.\n
# 28380  Bender: Well, looks like that wraps everything...
# 28390                                           Bender\n
#
#                                                      raw    name  \
# 71                  Bender: Shinier than yours, meatbag!  Bender
# 72     Bender: Listen, buddy, I'm in a hurry here. Le...  Bender
# 76                             Bender Bring it on, baby!  Bender
# ...

# %%
df = df[['name','dail']]
df
# Out:
#              name                                               dail
# 0             Fry   Space. It seems to go on and on forever. But ...
# 1             Fry                             how you play the game!
# 2             Boy                                  You stink, loser!
# 3         Panucci                 Hey, Fry. Pizza goin' out! C'mon!!
# 4             Fry                   Michelle, baby! Where you going?
# ...           ...                                                ...
# 28387      Hermes            Sweet topology of cosmology, it's huge!
# 28388  Farnsworth   If we fly into it, it could take us trillions...
# 28389         Fry                What do we do? Should we go for it?
# 28390      Bender
# 28391         ALL            Go, go, go, go, go, go, go, go, go, go.
#
# [28392 rows x 2 columns]

# %%
def remove_punk(s):
    s = ''.join([l for l in s if l not in string.punctuation])
    return s

# %%
df['name'] = df['name'].apply(remove_punk)
# Out:
# /home/brando/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cdf = pd.DataFrame(df['name'].unique(),columns=['Charicters'])#.iloc[:30]
cdf
# Out:
#                                              Charicters
# 0                                                   Fry
# 1                                                   Boy
# 2                                               Panucci
# 3                                              Michelle
# 4                                            Bike Thief
# ...                                                 ...
# 1632                                Ruth Ginsbergs Head
# 1633                                Lincoln on a 5 bill
# 1634                                                Zap
# 1635                         Nixons Head Telepathically
# 1636  Mysterious Sinister Voice Telepathically to Mr...
#
# [1637 rows x 1 columns]

# %%
df['name'] = df.['name'].str
# Out:
#              name                                               dail
# 0             Fry   Space. It seems to go on and on forever. But ...
# 1             Fry                             how you play the game!
# 2             Boy                                  You stink, loser!
# 3         Panucci                 Hey, Fry. Pizza goin' out! C'mon!!
# 4             Fry                   Michelle, baby! Where you going?
# ...           ...                                                ...
# 28387      Hermes            Sweet topology of cosmology, it's huge!
# 28388  Farnsworth   If we fly into it, it could take us trillions...
# 28389         Fry                What do we do? Should we go for it?
# 28390      Bender
# 28391         ALL            Go, go, go, go, go, go, go, go, go, go.
#
# [28392 rows x 2 columns]

# %%
df.head(200)
# Out:
#             name                                               dail
# 0            Fry   Space. It seems to go on and on forever. But ...
# 1            Fry                             how you play the game!
# 2            Boy                                  You stink, loser!
# 3        Panucci                 Hey, Fry. Pizza goin' out! C'mon!!
# 4            Fry                   Michelle, baby! Where you going?
# 5       Michelle              I put your stuff out on the sidewalk!
# 6            Fry    I hate my life, I hate my life, I hate my life.
# 7     Bike Thief                                    Happy new year!
# 8            Fry                Here's to another lousy millennium.
# 9          Crowd                                               Ten!
# 10         Crowd                                              Neuf!
# 11         Crowd                                              Otto!
# 12         Crowd                                              Saba!
# ...

# %%
df['prev'] = df['dail'].shift()
df
# Out:
# /home/brando/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#              name                                               dail  \
# 0             Fry   Space. It seems to go on and on forever. But ...
# 1             Fry                             how you play the game!
# 2             Boy                                  You stink, loser!
# 3         Panucci                 Hey, Fry. Pizza goin' out! C'mon!!
# 4             Fry                   Michelle, baby! Where you going?
# ...           ...                                                ...
# 28387      Hermes            Sweet topology of cosmology, it's huge!
# ...

# %%
df = df[['name','dail','prev']]
df
# Out:
#              name                                               dail  \
# 0             Fry   Space. It seems to go on and on forever. But ...
# 1             Fry                             how you play the game!
# 2             Boy                                  You stink, loser!
# 3         Panucci                 Hey, Fry. Pizza goin' out! C'mon!!
# 4             Fry                   Michelle, baby! Where you going?
# ...           ...                                                ...
# 28387      Hermes            Sweet topology of cosmology, it's huge!
# 28388  Farnsworth   If we fly into it, it could take us trillions...
# 28389         Fry                What do we do? Should we go for it?
# 28390      Bender
# 28391         ALL            Go, go, go, go, go, go, go, go, go, go.
#
#                                                     prev
# 0                                                    NaN
# 1       Space. It seems to go on and on forever. But ...
# ...

# %%
df.iloc[:200]
# Out:
#             name                                               dail  \
# 0            Fry   Space. It seems to go on and on forever. But ...
# 1            Fry                             how you play the game!
# 2            Boy                                  You stink, loser!
# 3        Panucci                 Hey, Fry. Pizza goin' out! C'mon!!
# 4            Fry                   Michelle, baby! Where you going?
# 5       Michelle              I put your stuff out on the sidewalk!
# 6            Fry    I hate my life, I hate my life, I hate my life.
# 7     Bike Thief                                    Happy new year!
# 8            Fry                Here's to another lousy millennium.
# 9          Crowd                                               Ten!
# 10         Crowd                                              Neuf!
# 11         Crowd                                              Otto!
# 12         Crowd                                              Saba!
# ...

# %%
#df.to_csv('Futurama_Dialog.csv',index=False)

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer

# Create a new chat bot named Charlie
chatbot = ChatBot('Charlie')

trainer = ListTrainer(chatbot)

trainer.train(list(df['dail'])
    _
'''
    "Hi, can I help you?",
    "Sure, I'd like to book a flight to Iceland.",
    "Your flight has been booked."
])'''
while True:
    req = input('YOU:')
        # Get a response to the input text 'I would like to book a flight.'
    response = chatbot.get_response('BOT:'+req)

    print(response)

# %%
from chatterbot import ChatBot
#from chatterbot.trainers import ChatterBotCorpusTrainer#ListTrainer
from chatterbot.trainers import ListTrainer

# Create a new chat bot named Charlie
chatbot = ChatBot('futurama')

trainer = ListTrainer(chatbot)

trainer.train(list(df['prev']))

# Get a response to the input text 'I would like to book a flight.'
#response = chatbot.get_response('I would like to book a flight.')

while True:
    req = input('YOU:')
    response = chatbot.get_response(req)

    print('BOT:',response)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-115-1c56910dd84c> in <module>
#       4
#       5 # Create a new chat bot named Charlie
# ----> 6 chatbot = ChatBot('futurama')
#       7
#       8 trainer = ListTrainer(chatbot)
#
# ~/anaconda3/lib/python3.7/site-packages/chatterbot/chatterbot.py in __init__(self, name, **kwargs)
#      26         self.logic_adapters = []
#      27
# ---> 28         self.storage = utils.initialize_class(storage_adapter, **kwargs)
#      29
#      30         primary_search_algorithm = IndexedTextSearch(self, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/chatterbot/utils.py in initialize_class(data, *args, **kwargs)
#      31         Class = import_module(data)
#      32
# ---> 33         return Class(*args, **kwargs)
#      34
#      35
#
# ...

# %% [markdown]
# # Remove names from things

# %%
df
s = df['raw'][0]
s
# Out:
# 'Fry: Space. It seems to go on and on forever. But then you get to the end and the gorilla starts throwing barrels at you.\n'

# %%
def characters(s):
    
    c = s.split(':')[0]
    return c

# %%
import string

# %%
df['raw'] = df['raw'].str.replace('\n','')

df
# Out:
#                                                        0  \
# 0      Fry: Space. It seems to go on and on forever. ...
# 1                           Fry how you play the game!\n
# 2                               Boy: You stink, loser!\n
# 3          Panucci: Hey, Fry. Pizza goin' out! C'mon!!\n
# 4                Fry: Michelle, baby! Where you going?\n
# ...                                                  ...
# 28387  Hermes: Sweet topology of cosmology, it's huge!\n
# 28388  Farnsworth: If we fly into it, it could take u...
# 28389         Fry: What do we do? Should we go for it?\n
# 28390                                           Bender\n
# 28391     ALL: Go, go, go, go, go, go, go, go, go, go.\n
#
#                                                      raw  \
# 0      Fry: Space. It seems to go on and on forever. ...
# 1                             Fry how you play the game!
# 2                                 Boy: You stink, loser!
# ...

# %%
df['raw'] = df['raw'].str.split(':',expand=True)[1]

df
# Out:
#                                                        0  \
# 0      Fry: Space. It seems to go on and on forever. ...
# 1                           Fry how you play the game!\n
# 2                               Boy: You stink, loser!\n
# 3          Panucci: Hey, Fry. Pizza goin' out! C'mon!!\n
# 4                Fry: Michelle, baby! Where you going?\n
# ...                                                  ...
# 28387  Hermes: Sweet topology of cosmology, it's huge!\n
# 28388  Farnsworth: If we fly into it, it could take u...
# 28389         Fry: What do we do? Should we go for it?\n
# 28390                                           Bender\n
# 28391     ALL: Go, go, go, go, go, go, go, go, go, go.\n
#
#                                                      raw  \
# 0       Space. It seems to go on and on forever. But ...
# 1                                                   None
# 2                                      You stink, loser!
# ...

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
import string
import re
import cufflinks as cf
cf.go_offline(connected=False)


text = u'This is a smiley face \U0001f602'
print(text) # with emoji

def deEmojify(text):
        regrex_pattern = re.compile(pattern = "["
                                            u"\U0001F600-\U0001F64F"  # emoticons
                                            u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                                            u"\U0001F680-\U0001F6FF"  # transport & map symbols
                                            u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                                                               "]+", flags = re.UNICODE)
            return regrex_pattern.sub(r'',text)
        
        print(deEmojify(text))
        
        def clean_text(text):
            #print(text)
                #removing numbers
                    text = re.sub(r'\d+', '', text)
                        # remove emojis
                            text = deEmojify(text)
                                #splitting word up
                                    text = word_tokenize(text)
                                    
                                        text = [l for l in text if l not in string.punctuation]
                                            text = [word for word in text if not word in stopwords.words('english')]
                                                text = ' '.join(text)
                                                    # only collect small words
                                                        smal = [word for word in text.split() if (2<len(word)<5)]
                                                        
                                                            return text
                                                                
                                                                #else:
                                                                    #    tics = []
                                                                        #return tics
                                                                        df['CleanText'] = df['Text'].apply(clean_text)
                                                                        
                                                                        #s = [l for l in text if l not in string.punctuation]
                                                                        #text =[ re.sub(r'\d+', '', w) for w in s]
                                                                        def extract_tickers(s):
                                                                                '''
                                                                                    give me tweets i spit out a list of words with NO DIGITS that had
                                                                                        hash tag "$" in the word
                                                                                            '''
                                                                                    
                                                                                        #s = df['Text'][5]
                                                                                            #print(s)
                                                                                                # grab Dollars
                                                                                                    s = [w for w in s.split(' ') if '$' in w]
                                                                                                        #print(s)
                                                                                                            goodli = []
                                                                                                                for w in s:
                                                                                                                            result = ''.join([i for i in w if not i.isdigit()])
                                                                                                                                #print('RESULT:',result, 'WORD:',w)
                                                                                                                                    if len(w) == len(result):
                                                                                                                                                #print('====GOOD====',w)
                                                                                                                                                    goodli.append(re.sub(r'\d+', '', w.replace('$','')))
                                                                                                                                                    else:
                                                                                                                                                                #print('====NAH====',w)
                                                                                                                                                                
                                                                                                                                                                
                                                                                                                                                                
                                                                                                                                                                    #print(goodli)
                                                                                                                                                                        return goodli
                                                                                                                                                                        
                                                                                                                                                                        ')))]")

# %%
import sqlalchemy as sql
import pandas as pd
eng = sql.create_engine('postgresql://postgres:password@localhost/stock_market')

# List tables 
con = eng.connect()
print(eng.table_names())


#Load Data From The Base
a=pd.read_sql_query('select * from "PW_15min"',con=eng).set_index('date')

# Add Columns If Not In Database
left_overs = set(df.columns) - set(a.columns)
print('columns in Database:',len(left_overs),left_overs)
if len(left_overs) > 0:
        for col in left_overs:
                    con.execute('ALTER TABLE {} ADD COLUMN "{}" TEXT NULL;'.format(table_name,col))
                        
                    
                    
                    # Save Data To Base
                    df.to_sql(table_name,con,if_exists = 'append', index = True)
                    
                    con.close()
